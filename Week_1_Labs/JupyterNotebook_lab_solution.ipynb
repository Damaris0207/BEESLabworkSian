# %% [markdown]
# # Who are you and where are you going?

# %% [markdown]
# #### Index
# + [Introduction](#Introduction)
# + [Name input](#Name)
# + [Profile](#Profile)
# + [Destination](#Destination)
# + [Image of the area](#Media)
# + [Activity suggestions](#Activities)
# + [Video of the Brecon Beacons](#Video)

# %% [markdown]
# ### Introduction  <a id='Introduction'></a>
#
# this notebook is to capture your name and save your holiday preferences

# %% [markdown]
# <a id='Name'></a>

# %%
#Name Input 
name = input('Please enter your name: ')
# Out:
# Please enter your name: Sian

# %% [markdown]
# <a id='Profile'></a>

# %%
#Profile Picture
from IPython.display import Image
Image(filename='sian2.jpg')

# %% [markdown]
# <a id='Destination'></a>

# %%
destination = input('where do you like going on holiday: ')
# Out:
# where do you like going on holiday: the mountains

# %%
specific= input('is there a specific area: ')
# Out:
# is there a specific area: brecon beacons

# %% [markdown]
# ### What does that look like ?
#
# <a id='Media'></a>

# %%
#this is an image of me hiking the Fan y Big loop on a sunny day
Image(filename='fan.jpg')

# %% [markdown]
# <a id='Activities'></a>
#
# ### Things to do there:
# +
# <span style='color:Green'> hike the mountains  </span>
# +
# <span style='color:Blue'> wild swim  </span>
# +
# <span style='color:Grey'> Talk to sheep  </span>

# %%
from IPython.display import HTML

# %% [markdown]
# <a id='Video'></a>

# %%
#a video of the same peak from youtube
HTML('<iframe frameborder="0" scrolling="no" marginheight="0" marginwidth="0"width="788.54" height="443" type="text/html" src="https://www.youtube.com/embed/zqVZssmMvOI?autoplay=0&fs=0&iv_load_policy=3&showinfo=0&rel=0&cc_load_policy=0&start=0&end=0&origin=https://youtubeembedcode.com"><div><small><a href="https://youtubeembedcode.com/de/">youtubeembedcode de</a></small></div><div><small><a href="https://enableflashplayer.com">Enable flash in chrome</a></small></div><div><small><a href="https://youtubeembedcode.com/en">youtubeembedcode en</a></small></div><div><small><a href="https://embedvimeovideo.com">Vimeo embed</a></small></div></iframe>')
# Out:
# <iframe frameborder="0" scrolling="no" marginheight="0" marginwidth="0"width="788.54" height="443" type="text/html" src="https://www.youtube.com/embed/zqVZssmMvOI?autoplay=0&fs=0&iv_load_policy=3&showinfo=0&rel=0&cc_load_policy=0&start=0&end=0&origin=https://youtubeembedcode.com"><div><small><a href="https://youtubeembedcode.com/de/">youtubeembedcode de</a></small></div><div><small><a href="https://enableflashplayer.com">Enable flash in chrome</a></small></div><div><small><a href="https://youtubeembedcode.com/en">youtubeembedcode en</a></small></div><div><small><a href="https://embedvimeovideo.com">Vimeo embed</a></small></div></iframe>
